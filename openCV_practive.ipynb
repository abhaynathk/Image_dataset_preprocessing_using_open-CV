# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10

# %%
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Print dataset shape
print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)

# Number of images to preprocess (for demonstration)
num_images = 5
# Out:
# ...
# 170498071/170498071 [==============================] - 4097s 24us/step
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)

# %%
# Preprocess images using OpenCV
def preprocess_image(image):
    # Resize to 64x64 for demonstration (CIFAR images are 32x32)
    resized_image = cv2.resize(image, (64, 64))
    # Convert to grayscale
    grayscale_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
    # Normalize (scaling pixel values to [0, 1])
    normalized_image = grayscale_image / 255.0
    return normalized_image

# Preprocess the first few images and display them
num_images = 5
for i in range(num_images):
    original_image = x_train[i]
    # Convert from RGB to BGR (OpenCV format)
    bgr_image = cv2.cvtColor(original_image, cv2.COLOR_RGB2BGR)
    preprocessed_image = preprocess_image(bgr_image)

    plt.figure(figsize=(8, 4))
    # Original Image
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
    plt.title("Original Image")
    # Preprocessed Image (Grayscale)
    plt.subplot(1, 2, 2)
    plt.imshow(preprocessed_image, cmap='gray')
    plt.title("Preprocessed Image (64x64 Grayscale)")
    plt.show()
